# %% [markdown]
# <a href="https://colab.research.google.com/github/s0963718122-blip/02/blob/main/d1%E8%AE%8A%E6%95%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=1
type(a)
# Out:
# int

# %%
b='abc'
type(b)
# Out:
# str

# %%
e=True
type(e)
# Out:
# bool

# %%
d=1.12
type(d)
# Out:
# float
